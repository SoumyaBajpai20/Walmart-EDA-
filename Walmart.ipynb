# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("D:\Dataset\Walmart Sales.csv")
df
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# <>:1: SyntaxWarning: invalid escape sequence '\D'
# C:\Users\HP\AppData\Local\Temp\ipykernel_11840\3519958588.py:1: SyntaxWarning: invalid escape sequence '\D'
#   df=pd.read_csv("D:\Dataset\Walmart Sales.csv")
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      A  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      B     Yangon        Member    Male
# 4    373-73-7910      C     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      A  Naypyitaw        Normal    Male
# 996  303-96-2227      A   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      B     Yangon        Normal    Male
# 999  849-09-3807      C     Yangon        Member  Female
#
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Date', 'Time', 'Payment',
#        'Rating'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   int64
#  8   Date           1000 non-null   object
#  9   Time           1000 non-null   object
#  10  Payment        1000 non-null   object
#  11  Rating         1000 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 93.9+ KB

# %%
df.describe()
# Out:
#         Unit price     Quantity      Rating
# count  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000     6.97270
# std      26.494628     2.923431     1.71858
# min      10.080000     1.000000     4.00000
# 25%      32.875000     3.000000     5.50000
# 50%      55.230000     5.000000     7.00000
# 75%      77.935000     8.000000     8.50000
# max      99.960000    10.000000    10.00000

# %%
df['amount']=df['Rating']*df['Unit price']
df[['Rating', 'amount']].describe()
# Out:
#            Rating       amount
# count  1000.00000  1000.000000
# mean      6.97270   387.785793
# std       1.71858   212.753855
# min       4.00000    41.656000
# 25%       5.50000   215.400500
# 50%       7.00000   358.938000
# 75%       8.50000   531.398500
# max      10.00000   986.931000

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      A  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      B     Yangon        Member    Male
# 4  373-73-7910      C     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity        Date   Time  \
# 0       Health and beauty       74.69         7  01-05-2019  13:08
# 1  Electronic accessories       15.28         5  03-08-2019  10:29
# 2      Home and lifestyle       46.33         7  03-03-2019  13:23
# 3       Health and beauty       58.22         8   1/27/2019  20:33
# 4       Sports and travel       86.31         7  02-08-2019  10:37
#
#        Payment  Rating   amount
# 0      Ewallet     9.1  679.679
# 1         Cash     9.6  146.688
# 2  Credit card     7.4  342.842
# 3      Ewallet     8.4  489.048
# 4      Ewallet     5.3  457.443

# %%
df.tail()
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 995  233-67-5758      A  Naypyitaw        Normal    Male    Health and beauty
# 996  303-96-2227      A   Mandalay        Normal  Female   Home and lifestyle
# 997  727-02-1313      A     Yangon        Member    Male   Food and beverages
# 998  347-56-2442      B     Yangon        Normal    Male   Home and lifestyle
# 999  849-09-3807      C     Yangon        Member  Female  Fashion accessories
#
#      Unit price  Quantity        Date   Time  Payment  Rating   amount
# 995       40.35         1   1/29/2019  13:46  Ewallet     6.2  250.170
# 996       97.38        10  03-02-2019  17:16  Ewallet     4.4  428.472
# 997       31.84         1  02-09-2019  13:22     Cash     7.7  245.168
# 998       65.82         1   2/22/2019  15:33     Cash     4.1  269.862
# 999       88.34         7   2/18/2019  13:28     Cash     6.6  583.044

# %%
df.drop(['Invoice ID', 'Date', 'Time'],axis=1,inplace=True)

# %%
Payment	=df['Payment'].value_counts().reset_index()
Payment
# Out:
#        Payment  count
# 0      Ewallet    345
# 1         Cash    344
# 2  Credit card    311

# %%
amount=df['amount'].sum()
Quantity=df['Quantity'].sum()

print(f'Total Amount :{round(amount,2)}')
print(f'Total Quantity :{Quantity}')
# Out:
# Total Amount :387785.79
# Total Quantity :5510

# %%
plt.figure(figsize =(4,3))
plt.bar(Payment['Payment'],Payment['count'],color='black',width=0.3)
plt.xlabel('Payment', color='red')
plt.ylabel('Rating',color='red')
plt.grid(color='red')
plt.show()

# %%
Payment_amount=df.groupby('Payment')[['amount']].sum().reset_index()
Payment_amount
# Out:
#        Payment      amount
# 0         Cash  136410.144
# 1  Credit card  118056.224
# 2      Ewallet  133319.425

# %%
plt.figure(figsize =(4,3))
plt.bar(Payment_amount['Payment'],Payment_amount['amount'],color='black',width=0.3)
plt.xlabel('Payment', color='red')
plt.ylabel('amount',color='red')
plt.grid(color='red')
plt.show()

# %%
amountbyProductline=df.groupby('Product line')[['amount']].sum().reset_index()
amountbyProductline
# Out:
#              Product line     amount
# 0  Electronic accessories  62222.510
# 1     Fashion accessories  72089.437
# 2      Food and beverages  69425.402
# 3       Health and beauty  58756.409
# 4      Home and lifestyle  59799.024
# 5       Sports and travel  65493.011

# %%
plt.figure(figsize=(5,4))
plt.bar(amountbyProductline['Product line'],amountbyProductline['amount'],color='black')
plt.plot(amountbyProductline['amount'],color='red',marker='.')
plt.xticks(rotation=90)
plt.xlabel('Product', color='red')
plt.ylabel('amount',color='red')
plt.grid()
plt.show()

# %%
plt.pie(amountbyProductline['amount'])
plt.legend(bbox_to_anchor=(1.05,1.0),labels=amountbyProductline['Product line'])
plt.show()

# %%
# Payment through Cash
data1=df.where(df['Payment']=='Cash')
data1.dropna(inplace=True)

# %%
amountByProductline=data1.groupby('Product line')[['Quantity', 'amount']].sum().reset_index()
amountByProductline
# Out:
#              Product line  Quantity     amount
# 0  Electronic accessories     398.0  25526.804
# 1     Fashion accessories     280.0  24519.110
# 2      Food and beverages     295.0  25905.682
# 3       Health and beauty     293.0  19102.737
# 4      Home and lifestyle     306.0  18519.019
# 5       Sports and travel     324.0  22836.792

# %%
plt.figure(figsize=(5,4))
plt.bar(amountbyProductline['Product line'],amountbyProductline['amount'],color='black')
plt.plot(amountbyProductline['amount'],color='red',marker='.')
plt.xticks(rotation=90)
plt.xlabel('Product', color='red')
plt.ylabel('amount',color='red')
plt.grid()
plt.show()

# %%
# Payment throught Credit card

data2=df.where(df['Payment']=='Credit card')
data2.dropna(inplace=True)

# %%
amountByProductline=data2.groupby('Product line')[['Quantity', 'amount']].sum().reset_index()
amountByProductline
# Out:
#              Product line  Quantity     amount
# 0  Electronic accessories     262.0  17489.708
# 1     Fashion accessories     293.0  21587.463
# 2      Food and beverages     335.0  23889.710
# 3       Health and beauty     274.0  19097.123
# 4      Home and lifestyle     259.0  15015.517
# 5       Sports and travel     299.0  20976.703

# %%
c=np.arange(len(amountbyProductline['Product line']))
plt.xticks(c,amountbyProductline['Product line'],rotation=90)
plt.bar(c,amountbyProductline['Quantity'],width=0.5,label='Quantity',color='red')
plt.bar(c+0.3,amountbyProductline['amount'],width=0.5,label='Amount',color='black')
plt.xlabel('Product line',color='red')
plt.ylabel('Amount and Quantity',color='red')
plt.legend()
plt.show()

# %%
data3=df.where(df['Payment']=='Ewallet')
data3.dropna(inplace=True)

# %%
amountbyProductline=data3.groupby('Product line')[['Quantity', 'amount']].sum().reset_index()
amountbyProductline
# Out:
#              Product line  Quantity     amount
# 0  Electronic accessories     311.0  19205.998
# 1     Fashion accessories     329.0  25982.864
# 2      Food and beverages     322.0  19630.010
# 3       Health and beauty     287.0  20556.549
# 4      Home and lifestyle     346.0  26264.488
# 5       Sports and travel     297.0  21679.516

# %%
c=np.arange(len(amountbyProductline['Product line']))
plt.xticks(c,amountbyProductline['Product line'],rotation=90)
plt.bar(c,amountbyProductline['Quantity'],width=0.5,label='Quantity',color='red')
plt.bar(c+0.3,amountbyProductline['amount'],width=0.5,label='Amount',color='black')
plt.xlabel('Product line',color='red')
plt.ylabel('Amount and Quantity',color='red')
plt.legend()
plt.show()

# %% [markdown]
#  # Insights from EDA
#
#  1.Total Amount Earned is: 387785.79
#  2.Total Quantity Sold is:5510
#  3.Highly Sold Product is Fashion accessories and earned Rs.72089.437
#  4.Least Sold product is  Health and beauty and earned Rs. 25905.682
#
#  # Payment : Cash
#
# 1.Highly Sold Product is Fashion accessories and earned Rs.24519.110
# 2.Least Sold Product is Home and lifestyle	and earned Rs.18519.019
#
# # Payment : Credit Card
#
# 1.Highly Sold Product is Fashion accessories and earned Rs.21587.463
# 2.Least Sold Product is  Home and lifestyle	 and Earned Rs.15015.517
#
# # Payment : Ewallet
#
# 1.Highly Sold Product is Home and lifestyle and earned Rs 26264.488
# 2.Least Sold Product is Electronic accessories	and earned Rs 19205.998
